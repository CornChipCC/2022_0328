# %% [markdown]
# # Now your turn!
#
# Fashion MNIST!

# %%
'''
라이브러리들을 불러오자.
'''
import matplotlib.pyplot as plt
import tensorflow as tf
import random as rd

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %%
labels = { 0 : 'T-shirt/top',
          1 : 'Trouser',
          2 : 'Pullover',
          3 : 'Dress',
          4 : 'Coat',
          5 : 'Sandal',
          6 : 'Shirt',
          7 : 'Sneaker',
          8 : 'Bag',
          9 : 'Ankle boot' }

print(labels)

# %%
'''
Ctrl+Enter를 이용하여
반복 실행 해보자!
'''

id = rd.randrange(0,10000)

print('id = {}'.format(id))
print('다음 그림은 {} 입니다.'.format( labels[y_test[id]] ))
plt.imshow(x_test[id]  , cmap='Greys')
plt.show()

# %% [markdown]
# # 이미지를 '표준화' 스케일링 하시오.
#
# **표준화 : $ x_{scaled} = { x - mean(x) \over std(x)  }$**
#
# 표준화의 역할 :
# 1. 데이터의 평균을 0 으로 만들고
# 2. 표준편차를 1로 만듦
#
# **모든 전처리는 트레이닝셋의 규칙을 따른다.**

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # Y를 원 핫 인코딩 하시오.

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # 테크닉 추가 훈련 1
#
# **Sequential API 사용 권장**
#
# **기본 구조**
# 1. 인풋레이어
# 2. Flatten layer 활용(데이터 따로 reshape 안함)
# 3. Dense, 1024, swish
# 4. Dense, 1024, swish
# 5. Dense, 1024, swish
# 6. Output Layer
#
# **학습까지 시킬 것**
# 1. epochs는 10회로 제한
# 2. batch_size는 128
# 3. 벨리데이션셋 비율은 15%

# %%
####################
## Your code here ##
####################

# %%
####################
## Your code here ##
####################

# %% [markdown]
# # 테크닉 추가 훈련 FINAL
#
# **Sequential API 사용 권장**
#
# **기본 구조**
# 1. 인풋레이어
# 2. Flatten layer 활용(데이터 따로 reshape 안함)
# 3. Dense, 1024, swish
# 4. Batch normalization
# 4. Dropout, 30%
# 4. Dense, 1024, swish
# 4. Batch normalization
# 4. Dropout, 30%
# 5. Dense, 1024, swish
# 4. Batch normalization
# 4. Dropout, 30%
# 5. Dense, 1024, swish
# 6. Output Layer
#
# **학습까지 시킬 것**
# 0. adam 기본 옵션
# 1. Early Stopping
#     * validation loss를 모니터링 할 것
#     * 5번 안에 개선이 없다면 멈출 것
#     * 성능이 유지만 되어도 개선되었다고 정의
#     * verbose 1
#     * 학습 멈춘 후, 가장 성능 좋았을 때 가중치 복구
# 1. epochs는 10000
# 2. batch_size는 128
# 3. 벨리데이션셋 비율은 15%

# %%
####################
## Your code here ##
####################

# %%
####################
## Your code here ##
####################
